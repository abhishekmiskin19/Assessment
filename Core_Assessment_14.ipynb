# %%
import random


print("Welcome to python E-Note")
print("press 1 for generate Note")
print("Press 2 for view Note")
print("Press 3 for exit")

WE = ["Welcome to python E-Note",
"press 1 for generate Note",
"Press 2 for view Note",
"Press 3 for exit"]

num = int(input("Enter your choice : "))
if num == 1 :
# Name
    name = input("Enter Python E-Note Generate Name : ").lower()
    while name.isalnum():
        print("invalid name")

        name = input("Enter Python E-Note Generate Name : ").lower()

# Title
    title = input("Enter Python E-Note title : ").lower() # Python introducation
    while title.isalpha():
        print("invalid name")

        title = input("Enter Python E-Note title : ").lower()

# Contect
    contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
    while contect.isalnum():
        print("invalid name")

        contect = input("Enter E-Note contect : ").lower()
        
    for pr in WE:
        print(pr)
    
    num = int(input("Enter your choice : "))
    
    if num == 1 :
    # Name
        name = input("Enter Python E-Note Generate Name : ").lower()
        while name.isalnum():
            print("invalid name")

            name = input("Enter Python E-Note Generate Name : ").lower()

    # Title
        title = input("Enter Python E-Note title : ").lower() # Python introducation
        while not title.isalnum():
            print("invalid name")

            title = input("Enter Python E-Note title : ").lower()

    # Contect
        contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
        while contect.isalnum():
            print("invalid name")

            contect = input("Enter E-Note contect : ").lower()

    elif num == 2 :
        deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
        for i in deta:
            print(i)

    elif num == 3 :
        print("removed itme")
    
elif num == 2 :
    deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
    for i in deta:
        print(i)

elif num == 3 :
    print("removed itme")
# Out:
# Welcome to python E-Note
# press 1 for generate Note
# Press 2 for view Note
# Press 3 for exit
# Enter your choice : 1
# Enter Python E-Note Generate Name : Abhishek Miskin
# Enter Python E-Note title : Pyhton Django
# Enter E-Note contect : OOP
# Welcome to python E-Note
# press 1 for generate Note
# Press 2 for view Note
# Press 3 for exit
# Enter your choice : 2
# E-Note Title : pyhton django
# E-Note Description : oop
# Note Generator : abhishek miskin

# %%
print("Welcome to python E-Note")
print("press 1 for generate Note")
print("Press 2 for view Note")
print("Press 3 for exit")

WE = ["Welcome to python E-Note",
"press 1 for generate Note",
"Press 2 for view Note",
"Press 3 for exit"]

num = int(input("Enter your choice : "))
if num == 1 :
# Name
    name = input("Enter Python E-Note Generate Name : ").lower()
    while name.isalnum():
        print("invalid name")

        name = input("Enter Python E-Note Generate Name : ").lower()

# Title
    title = input("Enter Python E-Note title : ").lower() # Python introducation
    while not title.isalnum():
        print("invalid name")

        title = input("Enter Python E-Note title : ").lower()

# Contect
    contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
    while contect.isalnum():
        print("invalid name")

        contect = input("Enter E-Note contect : ").lower()
        
    for pr in WE:
        print(pr)
    
    num = int(input("Enter your choice : "))
    
    if num == 1 :
    # Name
        name = input("Enter Python E-Note Generate Name : ").lower()
        while name.isalnum():
            print("invalid name")

            name = input("Enter Python E-Note Generate Name : ").lower()

    # Title
        title = input("Enter Python E-Note title : ").lower() # Python introducation
        while title.isalnum():
            print("invalid name")

            title = input("Enter Python E-Note title : ").lower()

    # Contect
        contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
        while contect.isalnum():
            print("invalid name")

            contect = input("Enter E-Note contect : ").lower()

    elif num == 2 :
        deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
        for i in deta:
            print(i)

    elif num == 3 :
        print("removed itme")
    
elif num == 2 :
    deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
    for i in deta:
        print(i)

elif num == 3 :
    print("removed itme")
# Out:
# Welcome to python E-Note
# press 1 for generate Note
# Press 2 for view Note
# Press 3 for exit
# Enter your choice : 2
# E-Note Title : python
# E-Note Description : oops
# Note Generator : abhishek

# %%
print("Welcome to python E-Note")
print("press 1 for generate Note")
print("Press 2 for view Note")
print("Press 3 for exit")

WE = ["Welcome to python E-Note",
"press 1 for generate Note",
"Press 2 for view Note",
"Press 3 for exit"]

num = int(input("Enter your choice : "))
if num == 1 :
# Name
    name = input("Enter Python E-Note Generate Name : ").lower()
    while name.isalnum():
        print("invalid name")

        name = input("Enter Python E-Note Generate Name : ").lower()

# Title
    title = input("Enter Python E-Note title : ").lower() # Python introducation
    while title.isalnum():
        print("invalid name")

        title = input("Enter Python E-Note title : ").lower()

# Contect
    contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
    while not contect.isalnum():
        print("invalid name")

        contect = input("Enter E-Note contect : ").lower()
        
    for pr in WE:
        print(pr)
    
    num = int(input("Enter your choice : "))
    
    if num == 1 :
    # Name
        name = input("Enter Python E-Note Generate Name : ").lower()
        while name.isalnum():
            print("invalid name")

            name = input("Enter Python E-Note Generate Name : ").lower()

    # Title
        title = input("Enter Python E-Note title : ").lower() # Python introducation
        while title.isalnum():
            print("invalid name")

            title = input("Enter Python E-Note title : ").lower()

    # Contect
        contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
        while not contect.isalnum():
            print("invalid name")

            contect = input("Enter E-Note contect : ").lower()

    elif num == 2 :
        deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
        for i in deta:
            print(i)

    elif num == 3 :
        print("removed itme")
    
elif num == 2 :
    deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
    for i in deta:
        print(i)

elif num == 3 :
    print("removed itme")
# Out:
# Welcome to python E-Note
# press 1 for generate Note
# Press 2 for view Note
# Press 3 for exit
# Enter your choice : 3
# removed itme
