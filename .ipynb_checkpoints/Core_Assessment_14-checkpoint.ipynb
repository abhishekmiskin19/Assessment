# %%
import random


print("Welcome to python E-Note")
print("press 1 for generate Note")
print("Press 2 for view Note")
print("Press 3 for exit")

WE = ["Welcome to python E-Note",
"press 1 for generate Note",
"Press 2 for view Note",
"Press 3 for exit"]

num = int(input("Enter your choice : "))
if num == 1 :
# Name
    name = input("Enter Python E-Note Generate Name : ").lower()
    while name.isalnum():
        print("invalid name")

        name = input("Enter Python E-Note Generate Name : ").lower()

# Title
    title = input("Enter Python E-Note title : ").lower() # Python introducation
    while title.isalpha():
        print("invalid name")

        title = input("Enter Python E-Note title : ").lower()

# Contect
    contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
    while contect.isalnum():
        print("invalid name")

        contect = input("Enter E-Note contect : ").lower()
        
    for pr in WE:
        print(pr)
    
    num = int(input("Enter your choice : "))
    
    if num == 1 :
    # Name
        name = input("Enter Python E-Note Generate Name : ").lower()
        while name.isalnum():
            print("invalid name")

            name = input("Enter Python E-Note Generate Name : ").lower()

    # Title
        title = input("Enter Python E-Note title : ").lower() # Python introducation
        while not title.isalnum():
            print("invalid name")

            title = input("Enter Python E-Note title : ").lower()

    # Contect
        contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
        while contect.isalnum():
            print("invalid name")

            contect = input("Enter E-Note contect : ").lower()

    elif num == 2 :
        deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
        for i in deta:
            print(i)

    elif num == 3 :
        print("removed itme")
    
elif num == 2 :
    deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
    for i in deta:
        print(i)

elif num == 3 :
    print("removed itme")
# Out:
# Welcome to python E-Note
# press 1 for generate Note
# Press 2 for view Note
# Press 3 for exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 14>()
#       7 print("Press 3 for exit")
#       9 WE = ["Welcome to python E-Note",
#      10 "press 1 for generate Note",
#      11 "Press 2 for view Note",
#      12 "Press 3 for exit"]
# ---> 14 num = int(input("Enter your choice : "))
#      15 if num == 1 :
#      16 # Name
#      17     name = input("Enter Python E-Note Generate Name : ").lower()
#
# File ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# File ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py:1120, in Kernel._input_request(self, prompt, ident, parent, password)
#    1117             break
#    1118 except KeyboardInterrupt:
#    1119     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1120     raise KeyboardInterrupt("Interrupted by user") from None
#    1121 except Exception:
#    1122     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
print("Welcome to python E-Note")
print("press 1 for generate Note")
print("Press 2 for view Note")
print("Press 3 for exit")

WE = ["Welcome to python E-Note",
"press 1 for generate Note",
"Press 2 for view Note",
"Press 3 for exit"]

num = int(input("Enter your choice : "))
if num == 1 :
# Name
    name = input("Enter Python E-Note Generate Name : ").lower()
    while name.isalnum():
        print("invalid name")

        name = input("Enter Python E-Note Generate Name : ").lower()

# Title
    title = input("Enter Python E-Note title : ").lower() # Python introducation
    while not title.isalnum():
        print("invalid name")

        title = input("Enter Python E-Note title : ").lower()

# Contect
    contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
    while contect.isalnum():
        print("invalid name")

        contect = input("Enter E-Note contect : ").lower()
        
    for pr in WE:
        print(pr)
    
    num = int(input("Enter your choice : "))
    
    if num == 1 :
    # Name
        name = input("Enter Python E-Note Generate Name : ").lower()
        while name.isalnum():
            print("invalid name")

            name = input("Enter Python E-Note Generate Name : ").lower()

    # Title
        title = input("Enter Python E-Note title : ").lower() # Python introducation
        while title.isalnum():
            print("invalid name")

            title = input("Enter Python E-Note title : ").lower()

    # Contect
        contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
        while contect.isalnum():
            print("invalid name")

            contect = input("Enter E-Note contect : ").lower()

    elif num == 2 :
        deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
        for i in deta:
            print(i)

    elif num == 3 :
        print("removed itme")
    
elif num == 2 :
    deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
    for i in deta:
        print(i)

elif num == 3 :
    print("removed itme")
# Out:
# Welcome to python E-Note
# press 1 for generate Note
# Press 2 for view Note
# Press 3 for exit
# Enter your choice : 2
# E-Note Title : python
# E-Note Description : oops
# Note Generator : abhishek

# %%
print("Welcome to python E-Note")
print("press 1 for generate Note")
print("Press 2 for view Note")
print("Press 3 for exit")

WE = ["Welcome to python E-Note",
"press 1 for generate Note",
"Press 2 for view Note",
"Press 3 for exit"]

num = int(input("Enter your choice : "))
if num == 1 :
# Name
    name = input("Enter Python E-Note Generate Name : ").lower()
    while name.isalnum():
        print("invalid name")

        name = input("Enter Python E-Note Generate Name : ").lower()

# Title
    title = input("Enter Python E-Note title : ").lower() # Python introducation
    while title.isalnum():
        print("invalid name")

        title = input("Enter Python E-Note title : ").lower()

# Contect
    contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
    while not contect.isalnum():
        print("invalid name")

        contect = input("Enter E-Note contect : ").lower()
        
    for pr in WE:
        print(pr)
    
    num = int(input("Enter your choice : "))
    
    if num == 1 :
    # Name
        name = input("Enter Python E-Note Generate Name : ").lower()
        while name.isalnum():
            print("invalid name")

            name = input("Enter Python E-Note Generate Name : ").lower()

    # Title
        title = input("Enter Python E-Note title : ").lower() # Python introducation
        while title.isalnum():
            print("invalid name")

            title = input("Enter Python E-Note title : ").lower()

    # Contect
        contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
        while not contect.isalnum():
            print("invalid name")

            contect = input("Enter E-Note contect : ").lower()

    elif num == 2 :
        deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
        for i in deta:
            print(i)

    elif num == 3 :
        print("removed itme")
    
elif num == 2 :
    deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
    for i in deta:
        print(i)

elif num == 3 :
    print("removed itme")
# Out:
# Welcome to python E-Note
# press 1 for generate Note
# Press 2 for view Note
# Press 3 for exit
# Enter your choice : 3
# removed itme
