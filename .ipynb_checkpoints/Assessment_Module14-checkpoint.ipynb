# %%
import random
print("Welcome to python E-Note")
print("press 1 for generate Note")
print("Press 2 for view Note")
print("Press 3 for exit")

num = int(input("Enter your choice : "))
if num == 1 :
# Name
    name = input("Enter Python E-Note Generate Name : ").lower()
    while not name.isalpha():
        print("invalid name")

        name = input("Enter Python E-Note Generate Name : ").lower()

# Title
    title = input("Enter Python E-Note title : ").lower() # Python introducation
    while not title.isalpha():
        print("invalid name")

        title = input("Enter Python E-Note title : ").lower()

# Contect
    contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
    while not contect.isalpha():
        print("invalid name")

        contect = input("Enter E-Note contect : ").lower()
    
elif num == 2 :
    print("Press 2 for view Note")

elif num == 3 :
    import os
    print("removed itme")
# Out:
# Welcome to python E-Note
# press 1 for generate Note
# Press 2 for view Note
# Press 3 for exit
# Enter your choice : 2
# Press 2 for view Note

# %%
print("Welcome to python E-Note")
print("press 1 for generate Note")
print("Press 2 for view Note")
print("Press 3 for exit")

WE = ["Welcome to python E-Note",
"press 1 for generate Note",
"Press 2 for view Note",
"Press 3 for exit"]

num = int(input("Enter your choice : "))
if num == 1 :
# Name
    name = input("Enter Python E-Note Generate Name : ").lower()
    while not name.isalpha():
        print("invalid name")

        name = input("Enter Python E-Note Generate Name : ").lower()

# Title
    title = input("Enter Python E-Note title : ").lower() # Python introducation
    while not title.isalpha():
        print("invalid name")

        title = input("Enter Python E-Note title : ").lower()

# Contect
    contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
    while not contect.isalpha():
        print("invalid name")

        contect = input("Enter E-Note contect : ").lower()
        
    for pr in WE:
        print(pr)
    
    num = int(input("Enter your choice : "))
    
    if num == 1 :
    # Name
        name = input("Enter Python E-Note Generate Name : ").lower()
        while not name.isalpha():
            print("invalid name")

            name = input("Enter Python E-Note Generate Name : ").lower()

    # Title
        title = input("Enter Python E-Note title : ").lower() # Python introducation
        while not title.isalpha():
            print("invalid name")

            title = input("Enter Python E-Note title : ").lower()

    # Contect
        contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
        while not contect.isalpha():
            print("invalid name")

            contect = input("Enter E-Note contect : ").lower()

    elif num == 2 :
        deta = f"E-Note Title : {title} /n E-Note Description : {contect} /n              Note Generator : {name}"
        print(deta)

    elif num == 3 :
        print("removed itme")
    
elif num == 2 :
    deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
    for i in deta:
        print(i)

elif num == 3 :
    print("removed itme")
# Out:
# Welcome to python E-Note
# press 1 for generate Note
# Press 2 for view Note
# Press 3 for exit
# Enter your choice : 2
# E-Note Title : python
# E-Note Description : oops
# Note Generator : abhi

# %%
print("Welcome to python E-Note")
print("press 1 for generate Note")
print("Press 2 for view Note")
print("Press 3 for exit")

WE = ["Welcome to python E-Note",
"press 1 for generate Note",
"Press 2 for view Note",
"Press 3 for exit"]

num = int(input("Enter your choice : "))
if num == 1 :
# Name
    name = input("Enter Python E-Note Generate Name : ").lower()
    while not name.isalpha():
        print("invalid name")

        name = input("Enter Python E-Note Generate Name : ").lower()

# Title
    title = input("Enter Python E-Note title : ").lower() # Python introducation
    while not title.isalpha():
        print("invalid name")

        title = input("Enter Python E-Note title : ").lower()

# Contect
    contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
    while not contect.isalpha():
        print("invalid name")

        contect = input("Enter E-Note contect : ").lower()
        
    for pr in WE:
        print(pr)
    
    num = int(input("Enter your choice : "))
    
    if num == 1 :
    # Name
        name = input("Enter Python E-Note Generate Name : ").lower()
        while not name.isalpha():
            print("invalid name")

            name = input("Enter Python E-Note Generate Name : ").lower()

    # Title
        title = input("Enter Python E-Note title : ").lower() # Python introducation
        while not title.isalpha():
            print("invalid name")

            title = input("Enter Python E-Note title : ").lower()

    # Contect
        contect = input("Enter E-Note contect : ").lower() # Python higher level programing language
        while not contect.isalpha():
            print("invalid name")

            contect = input("Enter E-Note contect : ").lower()

    elif num == 2 :
        deta = f"E-Note Title : {title} /n E-Note Description : {contect} /n              Note Generator : {name}"
        print(deta)

    elif num == 3 :
        print("removed itme")
    
elif num == 2 :
    deta = [f"E-Note Title : {title}", f"E-Note Description : {contect}", f"Note Generator : {name}"]
    for i in deta:
        print(i)

elif num == 3 :
    print("removed itme")
# Out:
# Welcome to python E-Note
# press 1 for generate Note
# Press 2 for view Note
# Press 3 for exit
# Enter your choice : 1
# Enter Python E-Note Generate Name : Abhi
# Enter Python E-Note title : Python
# Enter E-Note contect : 2
# invalid name
